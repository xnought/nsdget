# %%
import pandas as pd
import numpy as np
from PIL import Image 
from nsdget import nsd_betas_images_trials, nsd_coco_image, nsd_single_trial_betas

# download and use data
df: pd.DataFrame = nsd_betas_images_trials(save_to="../nsdata/")
betas: np.ndarray = nsd_single_trial_betas(df.iloc[0]) # 1.8mm res fmri single trial from NSD for the given row (index 0 here) 
image0: Image = nsd_coco_image(df.iloc[0]) # crops how NSD did and gives you the PIL image (can easily be converted to numpy too)
image0
# Out:
# > Data in ./nsdata
# >> Downloading all Betas
# Downloading all session betas for subj01
# 100%|██████████| 40/40 [00:00<00:00, 133789.60it/s]
# Downloading all session betas for subj02
# 100%|██████████| 40/40 [00:00<00:00, 83510.28it/s]
# Downloading all session betas for subj03
# 100%|██████████| 32/32 [00:00<00:00, 180642.97it/s]
# Downloading all session betas for subj04
# 100%|██████████| 30/30 [00:00<00:00, 129720.74it/s]
# Downloading all session betas for subj05
# 100%|██████████| 40/40 [00:00<00:00, 189787.51it/s]
# Downloading all session betas for subj06
# 100%|██████████| 32/32 [00:00<00:00, 58178.47it/s]
# Downloading all session betas for subj07
# 100%|██████████| 40/40 [00:00<00:00, 170154.32it/s]
# Downloading all session betas for subj08
# 100%|██████████| 30/30 [00:00<00:00, 157090.04it/s]
# >> Downloading all COCO Images
# 100%|██████████| 73000/73000 [00:00<00:00, 238049.44it/s]
# >> Unrolling stimulu info into dataframe
# <PIL.Image.Image image mode=RGB size=425x425>

# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")

plt.imshow(betas[:, :, 83//2], cmap="inferno", vmin=0)
plt.colorbar()
